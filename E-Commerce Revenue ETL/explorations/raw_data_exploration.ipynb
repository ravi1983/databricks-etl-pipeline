# %%
# Order data
df = spark.read.csv('/Volumes/ecommerce/bronze/ingestion/orders/', header=True)
display(df.limit(5))

# %%
# Order items data
df = spark.read.csv('/Volumes/ecommerce/bronze/ingestion/order_items/', header=True)
display(df.limit(5))

# %%
# customer data
df = spark.read.csv('/Volumes/ecommerce/bronze/ingestion/customers/', header=True)
display(df.limit(5))

# %%
df.select('customer_id').distinct().count(), df.select('customer_unique_id').distinct().count()

# %%
# %sql

select current_schema();
